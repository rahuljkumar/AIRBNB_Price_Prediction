# %% [markdown]
# **Predicting prices of Airbnb**

# %% [markdown]
# **Life cycle of this Machine Learning project**
#
# *  Understanding the Problem Statement
# *  Data Collection
# *  Performing data checks
# *  Exploratory data analysis
# *  Data Pre-Processing
# *  Model Training
# *  Choosing best model

# %% [markdown]
# **Problem Statement**
#
# This Machine Learning project aims to predict the price of Airbnb based on inputs such as Location of Airbnb, Number of rooms, Property type, Reviews in the Airbnb platform, etc.

# %% [markdown]
# **Data Collection**
#
# * The dataset is sourced from this Website: https://data.beta.nyc/dataset/inside%C2%ADairbnb%C2%ADdata/resource/9d64399b%C2%AD36d6%C2%AD40a9%C2%ADb0bb%C2%ADf26ae0d9c53f
# * The dataset contains 27392 rows and 52 columns

# %% [markdown]
# Importing the libraries required

# %%
#Importing the basic libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings

#Importing libraries for preprocessing the data
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import RobustScaler, OneHotEncoder
from sklearn.model_selection import train_test_split

#Importing the evaluation metrics
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, explained_variance_score

#Importing the Regression algorithms
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.ensemble import GradientBoostingRegressor, AdaBoostRegressor
from catboost import CatBoostRegressor
warnings.filterwarnings('ignore')

# %%
#Reading the CSV dataset as a Pandas Dataframe
df = pd.read_csv('listings.csv')

# %%
#Checking if there are any duplicate records in the daset
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There are not duplicate records

# %%
#Checking the Shape of the dataset
df.shape
# Out:
# (27392, 52)

# %%
#Checking the first 5 rows of the dataset
df.head()
# Out:
#         id     scrape_id last_scraped                                 name  \
# 0  1069266  2.020000e+13   01-02-2015        Stay like a real New Yorker!
# 1  1846722  2.020000e+13   01-02-2015    Apartment 20 Minutes Times Square
# 2  2061725  2.020000e+13   01-02-2015  Option of 2 Beds w Private Bathroom
# 3    44974  2.020000e+13   01-03-2015  Charming Bright West Village Studio
# 4  4701675  2.020000e+13   01-02-2015        Charming Apartment in Chelsea
#
#                                          picture_url   host_id host_name  \
# 0  https://a0.muscache.com/pictures/50276484/larg...   5867023   Michael
# 1  https://a1.muscache.com/pictures/35865039/larg...   2631556    Denise
# 2  https://a2.muscache.com/pictures/50650147/larg...   4601412      Miao
# 3  https://a1.muscache.com/pictures/20489905/larg...    198425      Sara
# 4  https://a2.muscache.com/pictures/60588955/larg...  22590025   Charles
#
#    host_since                                   host_picture_url  \
# 0  04-10-2013  https://a2.muscache.com/ic/users/5867023/profi...
# 1     6/13/12  https://a2.muscache.com/ic/users/2631556/profi...
# 2  01-05-2013  https://a0.muscache.com/ic/users/4601412/profi...
# 3  08-11-2010  https://a0.muscache.com/ic/users/198425/profil...
# 4    10/15/14  https://a2.muscache.com/ic/users/22590025/prof...
#
#                                               street  ... first_review  \
# 0  East 53rd Street, New York, NY 10022, United S...  ...      4/28/13
# 1     West 155th Street, New York, NY, United States  ...   01-05-2014
# 2  Van Buren Street, Brooklyn, NY 11221, United S...  ...   02-04-2014
# 3   Greenwich Ave, New York, NY 10011, United States  ...   10-08-2010
# 4  West 22nd Street, New York, NY 10011, United S...  ...   12-08-2014
#
#   last_review review_scores_rating review_scores_accuracy  \
# 0    12/17/14                 86.0                    9.0
# 1    12/29/14                 85.0                    8.0
# 2    12/29/14                 98.0                   10.0
# 3    10/30/14                 96.0                   10.0
# 4  12-08-2014                100.0                   10.0
#
#   review_scores_cleanliness review_scores_checkin review_scores_communication  \
# 0                       7.0                   9.0                         9.0
# 1                       8.0                   9.0                         8.0
# 2                      10.0                  10.0                        10.0
# 3                       9.0                  10.0                        10.0
# 4                      10.0                  10.0                        10.0
#
#    review_scores_location  review_scores_value host_listing_count
# 0                    10.0                  9.0                  1
# 1                     7.0                  8.0                  2
# 2                     9.0                 10.0                  4
# 3                    10.0                  9.0                  1
# 4                    10.0                 10.0                  1
#
# [5 rows x 52 columns]

# %% [markdown]
# We can drop some of the features straight away because they do not contribute to the price of an Airbnb. Those features are:
#
# * id
# * scrape_id
# * last_scraped
# * name
# * picture_url
# * host_id
# * host_name
# * host_since
# * host_picture_url
# * calendar_updated

# %% [markdown]
# Some features have the same value for all records hence they can also be dropped. Those features are:
# * market
# * country

# %% [markdown]
# Some features carry the same information that the Latitude and Longitude hold. Hence they can also be dropped. Those features are:
# * neighbourhood
# * street
# * neighbourhood_cleansed
# * city
# * state
# * zipcode

# %%
#Checking the number of missing values in each column
df.isna().sum()
# Out:
# id                                 0
# scrape_id                          0
# last_scraped                       0
# name                               0
# picture_url                        0
# host_id                            0
# host_name                          0
# host_since                         0
# host_picture_url                   0
# street                             0
# neighbourhood                   2027
# neighbourhood_cleansed             0
# city                               0
# state                              2
# zipcode                          162
# market                             0
# country                            1
# latitude                           0
# longitude                          0
# is_location_exact                  0
# property_type                      6
# room_type                          0
# accommodates                       0
# bathrooms                        463
# bedrooms                         140
# beds                              98
# bed_type                           0
# square_feet                    26386
# price                              0
# weekly_price                   15374
# monthly_price                  17558
# guests_included                    0
# extra_people                       0
# minimum_nights                     0
# maximum_nights                     0
# calendar_updated                   0
# availability_30                    0
# availability_60                    0
# availability_90                    0
# availability_365                   0
# calendar_last_scraped              0
# number_of_reviews                  0
# first_review                    8364
# last_review                     8364
# review_scores_rating            8657
# review_scores_accuracy          8727
# review_scores_cleanliness       8731
# review_scores_checkin           8729
# review_scores_communication     8731
# review_scores_location          8732
# review_scores_value             8734
# host_listing_count                 0
# dtype: int64

# %% [markdown]
# The below features have missing values for a large number of records. Hence they cannot be imputed. Thus dropping those features completely. Those features are:
# * square_feet
# * weekly_price
# * monthly_price

# %%
#Listing the columns that are to be dropped completely
columns_to_drop = ['id','scrape_id','last_scraped','name','picture_url','host_id','host_name','host_since','host_picture_url','neighbourhood','market','country','street','neighbourhood_cleansed','city','state','zipcode','square_feet','weekly_price','monthly_price','calendar_updated']

# %%
#Dropping the columns that do not contribute to the price of an Airbnb
df=df.drop(columns=columns_to_drop)

# %%
#Checking the Shape of the dataset after dropping the irrelavant features
df.shape
# Out:
# (27392, 31)

# %%
#Checking the number of unique values in each column
df.nunique()
# Out:
# latitude                       27373
# longitude                      27357
# is_location_exact                  2
# property_type                     18
# room_type                          3
# accommodates                      16
# bathrooms                         15
# bedrooms                          11
# beds                              15
# bed_type                           5
# price                            452
# guests_included                   15
# extra_people                     107
# minimum_nights                    28
# maximum_nights                   189
# availability_30                   31
# availability_60                   61
# availability_90                   91
# availability_365                 366
# calendar_last_scraped              3
# number_of_reviews                171
# first_review                    1613
# last_review                      741
# review_scores_rating              56
# review_scores_accuracy             9
# review_scores_cleanliness          9
# review_scores_checkin              8
# review_scores_communication        8
# review_scores_location             8
# review_scores_value                9
# host_listing_count                19
# dtype: int64

# %%
#Checking the number of missing values in each column
df.isna().sum()
# Out:
# latitude                          0
# longitude                         0
# is_location_exact                 0
# property_type                     6
# room_type                         0
# accommodates                      0
# bathrooms                       463
# bedrooms                        140
# beds                             98
# bed_type                          0
# price                             0
# guests_included                   0
# extra_people                      0
# minimum_nights                    0
# maximum_nights                    0
# availability_30                   0
# availability_60                   0
# availability_90                   0
# availability_365                  0
# calendar_last_scraped             0
# number_of_reviews                 0
# first_review                   8364
# last_review                    8364
# review_scores_rating           8657
# review_scores_accuracy         8727
# review_scores_cleanliness      8731
# review_scores_checkin          8729
# review_scores_communication    8731
# review_scores_location         8732
# review_scores_value            8734
# host_listing_count                0
# dtype: int64

# %% [markdown]
# Since we have sufficient amount of data we can drop the records where some of the values are missing

# %%
#Dropping the records with missing values
columns_to_drop_na = ['review_scores_rating',
'review_scores_accuracy',
'review_scores_cleanliness',
'review_scores_checkin',
'review_scores_communication',
'review_scores_location',
'review_scores_value','bathrooms','bedrooms','beds','property_type']
df = df.dropna(subset=columns_to_drop_na)

# %%
#Checking the number of missing values after dropping the nan values
df.isna().sum()
# Out:
# latitude                       0
# longitude                      0
# is_location_exact              0
# property_type                  0
# room_type                      0
# accommodates                   0
# bathrooms                      0
# bedrooms                       0
# beds                           0
# bed_type                       0
# price                          0
# guests_included                0
# extra_people                   0
# minimum_nights                 0
# maximum_nights                 0
# availability_30                0
# availability_60                0
# availability_90                0
# availability_365               0
# calendar_last_scraped          0
# number_of_reviews              0
# first_review                   0
# last_review                    0
# review_scores_rating           0
# review_scores_accuracy         0
# review_scores_cleanliness      0
# review_scores_checkin          0
# review_scores_communication    0
# review_scores_location         0
# review_scores_value            0
# host_listing_count             0
# dtype: int64

# %% [markdown]
# None of the columns have missing values now

# %%
#Checking the shape of the dataframe after dropping the records with missing values
df.shape
# Out:
# (18131, 31)

# %% [markdown]
# We still have sufficient amount of records even after dropping the records with missing values

# %%
#Converting the columns with dates to a standard format
date_columns = ['calendar_last_scraped', 'first_review','last_review']
df[date_columns] = df[date_columns].apply(pd.to_datetime)

# %%
#Defining a list of numerical columns which will be used for scaling
numeric_columns = ['latitude',
'longitude',
'accommodates',
'bathrooms',
'bedrooms',
'beds',
'guests_included',
'extra_people',
'minimum_nights',
'maximum_nights',
'availability_30',
'availability_60',
'availability_90',
'availability_365',
'number_of_reviews',
'review_scores_rating',
'review_scores_accuracy',
'review_scores_cleanliness',
'review_scores_checkin',
'review_scores_communication',
'review_scores_location',
'review_scores_value',
'host_listing_count',
'host_listing_count']

# %%
#Defining a list of categorical columns which will be used for encoding
categorical_columns = ['is_location_exact',
'property_type',
'room_type',
'bed_type']

# %%
#Removing the $ symbol from the columns having price
df['price'] = pd.to_numeric(df['price'].str.replace('[\$,]', '', regex=True))
df['extra_people'] = pd.to_numeric(df['extra_people'].str.replace('[\$,]', '', regex=True))

# %%
#Plotting a histogram of the price 
df.price.hist()
# Out:
# <Axes: >

# %% [markdown]
# The price column is skewed towards one side. We can apply log to bring it to a normal distribution

# %%
#Applying log to the price
df['price'] = np.log(df['price'].values)

# %%
#Plotting a histogram of the price after log
df.price.hist()
# Out:
# <Axes: >

# %% [markdown]
# The price is now normally distributed after applying log

# %%
# Use describe() to get basic statistics for numerical variables
numeric_stats = df.describe()

# Display the statistics
print(numeric_stats)
# Out:
#            latitude     longitude  accommodates     bathrooms      bedrooms  \
# count  18131.000000  18131.000000  18131.000000  18131.000000  18131.000000
# mean      40.733163    -73.964583      2.959076      1.106254      1.126138
# min       40.509611    -74.239539      1.000000      0.000000      0.000000
# 25%       40.701197    -73.988203      2.000000      1.000000      1.000000
# 50%       40.727444    -73.966064      2.000000      1.000000      1.000000
# 75%       40.763873    -73.947615      4.000000      1.000000      1.000000
# max       40.907704    -73.726710     16.000000      8.000000     10.000000
# std        0.047841      0.033707      1.760786      0.352013      0.640279
#
#                beds         price  guests_included  extra_people  \
# count  18131.000000  18131.000000     18131.000000  18131.000000
# mean       1.558767      4.852603         1.549004     16.092438
# min        1.000000      2.302585         0.000000      0.000000
# 25%        1.000000      4.442651         1.000000      0.000000
# 50%        1.000000      4.859812         1.000000     10.000000
# 75%        2.000000      5.247024         2.000000     25.000000
# max       16.000000      8.517193        16.000000    999.000000
# std        1.156724      0.579499         1.065459     23.311799
#
#        minimum_nights  ...                   first_review  \
# count    18131.000000  ...                          18131
# mean         2.502234  ...  2013-11-27 19:31:47.517511424
# min          1.000000  ...            2008-10-06 00:00:00
# 25%          1.000000  ...            2013-05-21 00:00:00
# 50%          2.000000  ...            2014-04-21 00:00:00
# 75%          3.000000  ...            2014-09-11 00:00:00
# max         30.000000  ...            2015-01-02 00:00:00
# std          2.310444  ...                            NaN
#
#                          last_review  review_scores_rating  \
# count                          18131          18131.000000
# mean   2014-10-10 14:50:14.461419776             92.242237
# min              2011-03-22 00:00:00             20.000000
# 25%              2014-10-02 00:00:00             89.000000
# 50%              2014-11-24 00:00:00             94.000000
# 75%              2014-12-15 00:00:00             99.000000
# max              2015-01-03 00:00:00            100.000000
# std                              NaN              8.291497
#
#        review_scores_accuracy  review_scores_cleanliness  \
# count            18131.000000               18131.000000
# mean                 9.369864                   9.016215
# min                  2.000000                   2.000000
# 25%                  9.000000                   9.000000
# 50%                 10.000000                   9.000000
# 75%                 10.000000                  10.000000
# max                 10.000000                  10.000000
# std                  0.891762                   1.164070
#
#       review_scores_checkin  review_scores_communication  \
# count          18131.000000                 18131.000000
# mean               9.579339                     9.668082
# min                2.000000                     2.000000
# 25%                9.000000                     9.000000
# 50%               10.000000                    10.000000
# 75%               10.000000                    10.000000
# max               10.000000                    10.000000
# std                0.788102                     0.692507
#
#       review_scores_location review_scores_value  host_listing_count
# count           18131.000000        18131.000000        18131.000000
# mean                9.251007            9.129723            1.891401
# min                 2.000000            2.000000            1.000000
# 25%                 9.000000            9.000000            1.000000
# 50%                10.000000            9.000000            1.000000
# 75%                10.000000           10.000000            2.000000
# max                10.000000           10.000000           28.000000
# std                 0.970857            0.905365            2.330511
#
# [8 rows x 27 columns]

# %%
#Displaying the correlation between the features
df_corr = df[numeric_columns].corr()
df_corr
# Out:
#                              latitude  longitude  accommodates  bathrooms  \
# latitude                     1.000000   0.124191     -0.042876  -0.059469
# longitude                    0.124191   1.000000      0.021650   0.014902
# accommodates                -0.042876   0.021650      1.000000   0.350425
# bathrooms                   -0.059469   0.014902      0.350425   1.000000
# bedrooms                    -0.079481   0.029776      0.596076   0.388741
# beds                        -0.052555   0.052778      0.801752   0.381123
# guests_included             -0.034220  -0.004897      0.510144   0.199837
# extra_people                 0.020426  -0.028556      0.157733   0.074319
# minimum_nights              -0.003853  -0.028364     -0.029250  -0.002072
# maximum_nights              -0.030565  -0.043048     -0.001410  -0.003712
# availability_30              0.005159   0.059548      0.047603   0.017522
# availability_60             -0.010820   0.071527      0.044756   0.015874
# availability_90             -0.017761   0.080379      0.040231   0.015169
# availability_365            -0.043750   0.097063      0.015961   0.013068
# number_of_reviews            0.019387  -0.007026      0.040009  -0.037834
# review_scores_rating        -0.006086  -0.042598     -0.081715  -0.001572
# review_scores_accuracy      -0.002179  -0.015892     -0.072593  -0.022147
# review_scores_cleanliness   -0.011100   0.005128     -0.030192  -0.009522
# review_scores_checkin       -0.019481  -0.011880     -0.066782  -0.017317
# review_scores_communication -0.010299  -0.035328     -0.071755  -0.027505
# review_scores_location       0.050253  -0.327633     -0.091852  -0.029303
# review_scores_value          0.000018  -0.007225     -0.073239  -0.005609
# host_listing_count          -0.066112   0.099003      0.213657   0.150317
# host_listing_count          -0.066112   0.099003      0.213657   0.150317
#
#                              bedrooms      beds  guests_included  \
# latitude                    -0.079481 -0.052555        -0.034220
# longitude                    0.029776  0.052778        -0.004897
# accommodates                 0.596076  0.801752         0.510144
# bathrooms                    0.388741  0.381123         0.199837
# bedrooms                     1.000000  0.533984         0.433811
# beds                         0.533984  1.000000         0.386501
# guests_included              0.433811  0.386501         1.000000
# extra_people                 0.113424  0.127723         0.349702
# minimum_nights               0.024362 -0.012014         0.019331
# maximum_nights               0.004791  0.004087         0.000232
# availability_30              0.006583  0.052594         0.024558
# availability_60              0.011216  0.051650         0.028153
# availability_90              0.014540  0.049992         0.025733
# availability_365             0.024674  0.039235         0.015913
# number_of_reviews            0.018041  0.015229         0.069855
# review_scores_rating        -0.028447 -0.100268        -0.017227
# review_scores_accuracy      -0.040657 -0.102884        -0.008570
# review_scores_cleanliness   -0.005927 -0.056909         0.018482
# review_scores_checkin       -0.021091 -0.066573        -0.008917
# review_scores_communication -0.041661 -0.076317        -0.009575
# review_scores_location      -0.060786 -0.103827        -0.041992
# review_scores_value         -0.020807 -0.078698        -0.027918
# host_listing_count           0.050063  0.315754         0.044271
# host_listing_count           0.050063  0.315754         0.044271
#
#                              extra_people  minimum_nights  maximum_nights  \
# latitude                         0.020426       -0.003853       -0.030565
# longitude                       -0.028556       -0.028364       -0.043048
# accommodates                     0.157733       -0.029250       -0.001410
# bathrooms                        0.074319       -0.002072       -0.003712
# bedrooms                         0.113424        0.024362        0.004791
# beds                             0.127723       -0.012014        0.004087
# guests_included                  0.349702        0.019331        0.000232
# extra_people                     1.000000       -0.022573        0.000782
# minimum_nights                  -0.022573        1.000000       -0.003847
# maximum_nights                   0.000782       -0.003847        1.000000
# availability_30                  0.096673       -0.097362        0.011774
# availability_60                  0.102889       -0.097719        0.011678
# availability_90                  0.106854       -0.097982        0.011379
# availability_365                 0.093923       -0.074218        0.009484
# number_of_reviews                0.065600       -0.062435       -0.003907
# review_scores_rating            -0.001504        0.030897       -0.009598
# review_scores_accuracy          -0.020353        0.018044       -0.007692
# review_scores_cleanliness        0.019856        0.008497       -0.008769
# review_scores_checkin            0.003402        0.003227        0.000244
# review_scores_communication      0.005481        0.006152        0.002548
# review_scores_location           0.016107        0.023540       -0.007945
# review_scores_value             -0.029953        0.014417       -0.001768
# host_listing_count               0.044559       -0.036899        0.009141
# host_listing_count               0.044559       -0.036899        0.009141
#
#                              ...  number_of_reviews  review_scores_rating  \
# latitude                     ...           0.019387             -0.006086
# longitude                    ...          -0.007026             -0.042598
# accommodates                 ...           0.040009             -0.081715
# bathrooms                    ...          -0.037834             -0.001572
# bedrooms                     ...           0.018041             -0.028447
# beds                         ...           0.015229             -0.100268
# guests_included              ...           0.069855             -0.017227
# extra_people                 ...           0.065600             -0.001504
# minimum_nights               ...          -0.062435              0.030897
# maximum_nights               ...          -0.003907             -0.009598
# availability_30              ...           0.069497             -0.081438
# availability_60              ...           0.097965             -0.084251
# availability_90              ...           0.104691             -0.086596
# availability_365             ...           0.077734             -0.093526
# number_of_reviews            ...           1.000000             -0.012707
# review_scores_rating         ...          -0.012707              1.000000
# review_scores_accuracy       ...          -0.025057              0.644618
# review_scores_cleanliness    ...           0.012448              0.672751
# review_scores_checkin        ...           0.028315              0.553514
# review_scores_communication  ...          -0.000488              0.551088
# review_scores_location       ...          -0.007370              0.414999
# review_scores_value          ...          -0.007752              0.697165
# host_listing_count           ...           0.045073             -0.194988
# host_listing_count           ...           0.045073             -0.194988
#
#                              review_scores_accuracy  \
# latitude                                  -0.002179
# longitude                                 -0.015892
# accommodates                              -0.072593
# bathrooms                                 -0.022147
# bedrooms                                  -0.040657
# beds                                      -0.102884
# guests_included                           -0.008570
# extra_people                              -0.020353
# minimum_nights                             0.018044
# maximum_nights                            -0.007692
# availability_30                           -0.093885
# availability_60                           -0.096241
# availability_90                           -0.100162
# availability_365                          -0.105019
# number_of_reviews                         -0.025057
# review_scores_rating                       0.644618
# review_scores_accuracy                     1.000000
# review_scores_cleanliness                  0.553831
# review_scores_checkin                      0.431805
# review_scores_communication                0.424594
# review_scores_location                     0.295910
# review_scores_value                        0.580155
# host_listing_count                        -0.192037
# host_listing_count                        -0.192037
#
#                              review_scores_cleanliness  review_scores_checkin  \
# latitude                                     -0.011100              -0.019481
# longitude                                     0.005128              -0.011880
# accommodates                                 -0.030192              -0.066782
# bathrooms                                    -0.009522              -0.017317
# bedrooms                                     -0.005927              -0.021091
# beds                                         -0.056909              -0.066573
# guests_included                               0.018482              -0.008917
# extra_people                                  0.019856               0.003402
# minimum_nights                                0.008497               0.003227
# maximum_nights                               -0.008769               0.000244
# availability_30                              -0.031917              -0.039426
# availability_60                              -0.027344              -0.038675
# availability_90                              -0.027361              -0.040572
# availability_365                             -0.039466              -0.052557
# number_of_reviews                             0.012448               0.028315
# review_scores_rating                          0.672751               0.553514
# review_scores_accuracy                        0.553831               0.431805
# review_scores_cleanliness                     1.000000               0.415972
# review_scores_checkin                         0.415972               1.000000
# review_scores_communication                   0.402638               0.595616
# review_scores_location                        0.255409               0.261135
# review_scores_value                           0.562080               0.461839
# host_listing_count                           -0.126179              -0.148391
# host_listing_count                           -0.126179              -0.148391
#
#                              review_scores_communication  \
# latitude                                       -0.010299
# longitude                                      -0.035328
# accommodates                                   -0.071755
# bathrooms                                      -0.027505
# bedrooms                                       -0.041661
# beds                                           -0.076317
# guests_included                                -0.009575
# extra_people                                    0.005481
# minimum_nights                                  0.006152
# maximum_nights                                  0.002548
# availability_30                                -0.051183
# availability_60                                -0.053350
# availability_90                                -0.057068
# availability_365                               -0.067605
# number_of_reviews                              -0.000488
# review_scores_rating                            0.551088
# review_scores_accuracy                          0.424594
# review_scores_cleanliness                       0.402638
# review_scores_checkin                           0.595616
# review_scores_communication                     1.000000
# review_scores_location                          0.281441
# review_scores_value                             0.452774
# host_listing_count                             -0.161947
# host_listing_count                             -0.161947
#
#                              review_scores_location  review_scores_value  \
# latitude                                   0.050253             0.000018
# longitude                                 -0.327633            -0.007225
# accommodates                              -0.091852            -0.073239
# bathrooms                                 -0.029303            -0.005609
# bedrooms                                  -0.060786            -0.020807
# beds                                      -0.103827            -0.078698
# guests_included                           -0.041992            -0.027918
# extra_people                               0.016107            -0.029953
# minimum_nights                             0.023540             0.014417
# maximum_nights                            -0.007945            -0.001768
# availability_30                           -0.079479            -0.101393
# availability_60                           -0.085040            -0.105213
# availability_90                           -0.089833            -0.108640
# availability_365                          -0.107101            -0.112374
# number_of_reviews                         -0.007370            -0.007752
# review_scores_rating                       0.414999             0.697165
# review_scores_accuracy                     0.295910             0.580155
# review_scores_cleanliness                  0.255409             0.562080
# review_scores_checkin                      0.261135             0.461839
# review_scores_communication                0.281441             0.452774
# review_scores_location                     1.000000             0.388596
# review_scores_value                        0.388596             1.000000
# host_listing_count                        -0.188898            -0.133885
# host_listing_count                        -0.188898            -0.133885
#
#                              host_listing_count  host_listing_count
# latitude                              -0.066112           -0.066112
# longitude                              0.099003            0.099003
# accommodates                           0.213657            0.213657
# bathrooms                              0.150317            0.150317
# bedrooms                               0.050063            0.050063
# beds                                   0.315754            0.315754
# guests_included                        0.044271            0.044271
# extra_people                           0.044559            0.044559
# minimum_nights                        -0.036899           -0.036899
# maximum_nights                         0.009141            0.009141
# availability_30                        0.125165            0.125165
# availability_60                        0.138159            0.138159
# availability_90                        0.150183            0.150183
# availability_365                       0.150122            0.150122
# number_of_reviews                      0.045073            0.045073
# review_scores_rating                  -0.194988           -0.194988
# review_scores_accuracy                -0.192037           -0.192037
# review_scores_cleanliness             -0.126179           -0.126179
# review_scores_checkin                 -0.148391           -0.148391
# review_scores_communication           -0.161947           -0.161947
# review_scores_location                -0.188898           -0.188898
# review_scores_value                   -0.133885           -0.133885
# host_listing_count                     1.000000            1.000000
# host_listing_count                     1.000000            1.000000
#
# [24 rows x 24 columns]

# %%
# Create a heatmap using Seaborn to show correlation
plt.figure(figsize=(8, 6))
sns.heatmap(df_corr, annot=False, cmap='coolwarm', fmt=".2f", linewidths=0.1)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
#Splitting the Features and the Predictor into separate dataframes
X = df.drop('price', axis=1)
y = df['price']

# %%
#Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2, random_state = 40)
print("The shape of X_train is      ", X_train.shape)
print("The shape of X_test is       ",X_test.shape)
print("The shape of y_train is      ",y_train.shape)
print("The shape of y_test is       ",y_test.shape)
# Out:
# The shape of X_train is       (14504, 30)
# The shape of X_test is        (3627, 30)
# The shape of y_train is       (14504,)
# The shape of y_test is        (3627,)

# %% [markdown]
# **Data Preprocessing and Model training**

# %%
# Create transformers for scaling and one-hot encoding
numeric_transformer = Pipeline(steps=[
    ('scaler', RobustScaler())  # Use RobustScaler for scaling numeric features
])

categorical_transformer = Pipeline(steps=[
    ('onehot', OneHotEncoder(sparse=False, drop='first',handle_unknown='ignore'))  # Use OneHotEncoder for one-hot encoding categorical features
])

# Create a column transformer to apply transformers to respective columns
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_columns),
        ('cat', categorical_transformer, categorical_columns)
    ])

# Create a pipeline for preprocessing
preprocessing_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
])

# Fit and transform the training data
X_train_transformed = preprocessing_pipeline.fit_transform(X_train)

# Apply the same preprocessing to the testing set
X_test_transformed = preprocessing_pipeline.transform(X_test)

# %%
# Create a linear regression model
linear_regression_model = LinearRegression()

# Fit the model on the transformed training data
linear_regression_model.fit(X_train_transformed, y_train)

# Predict on the transformed testing set
y_pred = linear_regression_model.predict(X_test_transformed)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
explained_variance = explained_variance_score(y_test, y_pred)
# Calculate adjusted R-squared
n = X_test_transformed.shape[0]  # Number of samples
p = X_test_transformed.shape[1]  # Number of features
adjusted_r2 = 1 - ((1 - r2) * (n - 1) / (n - p - 1))
print(f'Linear Regression:')
print(f'Mean Squared Error (MSE): {mse}')
print(f'Mean Absolute Error (MAE): {mae}')
print(f'R-squared (R2): {r2}')
print(f'Explained Variance Score: {explained_variance}')
print(f'Adjusted R-squared: {adjusted_r2}')
# Out:
# Linear Regression:
# Mean Squared Error (MSE): 0.11174652179788255
# Mean Absolute Error (MAE): 0.2512530108891633
# R-squared (R2): 0.6811188706520999
# Explained Variance Score: 0.6811346170229395
# Adjusted R-squared: 0.6772018495210816

# %%
# Create a Lasso regression model
lasso_model = Lasso(alpha=1.0)  # You can adjust the alpha parameter for regularization

# Fit the model on the transformed training data
lasso_model.fit(X_train_transformed, y_train)

# Predict on the transformed testing set
y_pred = lasso_model.predict(X_test_transformed)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
explained_variance = explained_variance_score(y_test, y_pred)
# Calculate adjusted R-squared
n = X_test_transformed.shape[0]  # Number of samples
p = X_test_transformed.shape[1]  # Number of features
adjusted_r2 = 1 - ((1 - r2) * (n - 1) / (n - p - 1))
print(f'Lasso Regression:')
print(f'Mean Squared Error (MSE): {mse}')
print(f'Mean Absolute Error (MAE): {mae}')
print(f'R-squared (R2): {r2}')
print(f'Explained Variance Score: {explained_variance}')
print(f'Adjusted R-squared: {adjusted_r2}')
# Out:
# Lasso Regression:
# Mean Squared Error (MSE): 0.3502836935376617
# Mean Absolute Error (MAE): 0.469208015560367
# R-squared (R2): 0.00042651896159628944
# Explained Variance Score: 0.0008780909383951929
# Adjusted R-squared: -0.011851882257189361

# %%
# Create a Ridge regression model
ridge_model = Ridge(alpha=1.0)  # You can adjust the alpha parameter for regularization

# Fit the model on the transformed training data
ridge_model.fit(X_train_transformed, y_train)

# Predict on the transformed testing set
y_pred = ridge_model.predict(X_test_transformed)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
explained_variance = explained_variance_score(y_test, y_pred)
# Calculate adjusted R-squared
n = X_test_transformed.shape[0]  # Number of samples
p = X_test_transformed.shape[1]  # Number of features
adjusted_r2 = 1 - ((1 - r2) * (n - 1) / (n - p - 1))
print(f'Ridge Regression:')
print(f'Mean Squared Error (MSE): {mse}')
print(f'Mean Absolute Error (MAE): {mae}')
print(f'R-squared (R2): {r2}')
print(f'Explained Variance Score: {explained_variance}')
print(f'Adjusted R-squared: {adjusted_r2}')
# Out:
# Ridge Regression:
# Mean Squared Error (MSE): 0.11173424191214086
# Mean Absolute Error (MAE): 0.25127792373046737
# R-squared (R2): 0.681153912671937
# Explained Variance Score: 0.6811701348296554
# Adjusted R-squared: 0.6772373219844902

# %%
# Create a Gradient Boosting regression model
gradient_boost_model = GradientBoostingRegressor(
    n_estimators=100,  # Number of boosting stages
    learning_rate=0.1,  # Step size shrinkage to prevent overfitting
    max_depth=3,       # Maximum depth of the individual trees
    random_state=42    # For reproducibility
)

# Fit the model on the transformed training data
gradient_boost_model.fit(X_train_transformed, y_train)

# Predict on the transformed testing set
y_pred = gradient_boost_model.predict(X_test_transformed)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
explained_variance = explained_variance_score(y_test, y_pred)
# Calculate adjusted R-squared
n = X_test_transformed.shape[0]  # Number of samples
p = X_test_transformed.shape[1]  # Number of features
adjusted_r2 = 1 - ((1 - r2) * (n - 1) / (n - p - 1))
print(f'Gradient Boost:')
print(f'Mean Squared Error (MSE): {mse}')
print(f'Mean Absolute Error (MAE): {mae}')
print(f'R-squared (R2): {r2}')
print(f'Explained Variance Score: {explained_variance}')
print(f'Adjusted R-squared: {adjusted_r2}')
# Out:
# Gradient Boost:
# Mean Squared Error (MSE): 0.08413546711256815
# Mean Absolute Error (MAE): 0.21721982773783421
# R-squared (R2): 0.7599100863327521
# Explained Variance Score: 0.759936929463035
# Adjusted R-squared: 0.7569609081637518

# %%
# Create an AdaBoost regression model
adaboost_model = AdaBoostRegressor(
    base_estimator=None,  # You can specify a base estimator (e.g., DecisionTreeRegressor)
    n_estimators=50,      # Number of boosting stages
    learning_rate=1.0,    # Step size shrinkage to prevent overfitting
    random_state=42       # For reproducibility
)

# Fit the model on the transformed training data
adaboost_model.fit(X_train_transformed, y_train)

# Predict on the transformed testing set
y_pred = adaboost_model.predict(X_test_transformed)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
explained_variance = explained_variance_score(y_test, y_pred)
# Calculate adjusted R-squared
n = X_test_transformed.shape[0]  # Number of samples
p = X_test_transformed.shape[1]  # Number of features
adjusted_r2 = 1 - ((1 - r2) * (n - 1) / (n - p - 1))
print(f'AdaBoost:')
print(f'Mean Squared Error (MSE): {mse}')
print(f'Mean Absolute Error (MAE): {mae}')
print(f'R-squared (R2): {r2}')
print(f'Explained Variance Score: {explained_variance}')
print(f'Adjusted R-squared: {adjusted_r2}')
# Out:
# AdaBoost:
# Mean Squared Error (MSE): 0.13553317973733306
# Mean Absolute Error (MAE): 0.28625146515443356
# R-squared (R2): 0.6132409964676713
# Explained Variance Score: 0.6462800093883074
# Adjusted R-squared: 0.6084901879374025

# %%
# Create a CatBoost regression model
catboost_model = CatBoostRegressor(
    iterations=100,   # Number of boosting stages
    learning_rate=0.1, # Step size shrinkage to prevent overfitting
    depth=6,          # Depth of the trees
    random_seed=42     # For reproducibility
)

# Fit the model on the transformed training data
catboost_model.fit(X_train_transformed, y_train)

# Predict on the transformed testing set
y_pred = catboost_model.predict(X_test_transformed)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
explained_variance = explained_variance_score(y_test, y_pred)
# Calculate adjusted R-squared
n = X_test_transformed.shape[0]  # Number of samples
p = X_test_transformed.shape[1]  # Number of features
adjusted_r2 = 1 - ((1 - r2) * (n - 1) / (n - p - 1))
print(f'CatBoost:')
print(f'Mean Squared Error (MSE): {mse}')
print(f'Mean Absolute Error (MAE): {mae}')
print(f'R-squared (R2): {r2}')
print(f'Explained Variance Score: {explained_variance}')
print(f'Adjusted R-squared: {adjusted_r2}')
# Out:
# 0:	learn: 0.5427225	total: 8.05ms	remaining: 797ms
# 1:	learn: 0.5115038	total: 13.6ms	remaining: 668ms
# 2:	learn: 0.4842506	total: 19.5ms	remaining: 631ms
# 3:	learn: 0.4604461	total: 26ms	remaining: 624ms
# 4:	learn: 0.4403494	total: 31.7ms	remaining: 603ms
# 5:	learn: 0.4226792	total: 38.6ms	remaining: 605ms
# 6:	learn: 0.4069491	total: 44.6ms	remaining: 592ms
# 7:	learn: 0.3933622	total: 49.7ms	remaining: 572ms
# 8:	learn: 0.3811520	total: 56ms	remaining: 566ms
# 9:	learn: 0.3712322	total: 61.3ms	remaining: 552ms
# 10:	learn: 0.3627030	total: 67.2ms	remaining: 544ms
# 11:	learn: 0.3550375	total: 73.5ms	remaining: 539ms
# 12:	learn: 0.3482123	total: 78.6ms	remaining: 526ms
# 13:	learn: 0.3425490	total: 84.3ms	remaining: 518ms
# 14:	learn: 0.3374874	total: 90.3ms	remaining: 512ms
# 15:	learn: 0.3326472	total: 95.8ms	remaining: 503ms
# 16:	learn: 0.3284805	total: 102ms	remaining: 498ms
# 17:	learn: 0.3250436	total: 107ms	remaining: 489ms
# 18:	learn: 0.3215335	total: 113ms	remaining: 480ms
# 19:	learn: 0.3185919	total: 119ms	remaining: 475ms
# 20:	learn: 0.3158532	total: 124ms	remaining: 467ms
# 21:	learn: 0.3133054	total: 130ms	remaining: 459ms
# 22:	learn: 0.3103614	total: 136ms	remaining: 455ms
# 23:	learn: 0.3081436	total: 141ms	remaining: 446ms
# 24:	learn: 0.3061898	total: 146ms	remaining: 438ms
# 25:	learn: 0.3041075	total: 152ms	remaining: 433ms
# 26:	learn: 0.3023099	total: 157ms	remaining: 425ms
# 27:	learn: 0.3007759	total: 163ms	remaining: 419ms
# 28:	learn: 0.2994525	total: 169ms	remaining: 414ms
# 29:	learn: 0.2978895	total: 175ms	remaining: 408ms
# 30:	learn: 0.2962820	total: 182ms	remaining: 405ms
# 31:	learn: 0.2951154	total: 188ms	remaining: 400ms
# 32:	learn: 0.2938583	total: 195ms	remaining: 396ms
# 33:	learn: 0.2924640	total: 201ms	remaining: 390ms
# 34:	learn: 0.2914341	total: 207ms	remaining: 384ms
# 35:	learn: 0.2905697	total: 213ms	remaining: 378ms
# 36:	learn: 0.2897613	total: 219ms	remaining: 373ms
# 37:	learn: 0.2886349	total: 227ms	remaining: 370ms
# 38:	learn: 0.2878338	total: 233ms	remaining: 364ms
# 39:	learn: 0.2870153	total: 239ms	remaining: 359ms
# 40:	learn: 0.2863661	total: 246ms	remaining: 354ms
# 41:	learn: 0.2856043	total: 253ms	remaining: 349ms
# 42:	learn: 0.2849045	total: 258ms	remaining: 342ms
# 43:	learn: 0.2842178	total: 265ms	remaining: 337ms
# 44:	learn: 0.2836261	total: 271ms	remaining: 331ms
# 45:	learn: 0.2830982	total: 276ms	remaining: 324ms
# 46:	learn: 0.2825950	total: 282ms	remaining: 319ms
# 47:	learn: 0.2817662	total: 288ms	remaining: 312ms
# 48:	learn: 0.2812736	total: 296ms	remaining: 308ms
# 49:	learn: 0.2807256	total: 301ms	remaining: 301ms
# 50:	learn: 0.2803302	total: 306ms	remaining: 294ms
# 51:	learn: 0.2799047	total: 312ms	remaining: 288ms
# 52:	learn: 0.2795157	total: 317ms	remaining: 281ms
# 53:	learn: 0.2791090	total: 322ms	remaining: 275ms
# 54:	learn: 0.2784940	total: 329ms	remaining: 269ms
# 55:	learn: 0.2777609	total: 334ms	remaining: 262ms
# 56:	learn: 0.2774406	total: 339ms	remaining: 256ms
# 57:	learn: 0.2769115	total: 345ms	remaining: 250ms
# 58:	learn: 0.2765484	total: 351ms	remaining: 244ms
# 59:	learn: 0.2761344	total: 357ms	remaining: 238ms
# 60:	learn: 0.2757131	total: 362ms	remaining: 231ms
# 61:	learn: 0.2752027	total: 368ms	remaining: 225ms
# 62:	learn: 0.2748121	total: 374ms	remaining: 220ms
# 63:	learn: 0.2743207	total: 379ms	remaining: 213ms
# 64:	learn: 0.2739460	total: 385ms	remaining: 207ms
# 65:	learn: 0.2736288	total: 392ms	remaining: 202ms
# 66:	learn: 0.2733061	total: 400ms	remaining: 197ms
# 67:	learn: 0.2730863	total: 409ms	remaining: 192ms
# 68:	learn: 0.2728094	total: 416ms	remaining: 187ms
# 69:	learn: 0.2724942	total: 426ms	remaining: 183ms
# 70:	learn: 0.2722064	total: 433ms	remaining: 177ms
# 71:	learn: 0.2718921	total: 441ms	remaining: 171ms
# 72:	learn: 0.2715081	total: 448ms	remaining: 166ms
# 73:	learn: 0.2713730	total: 457ms	remaining: 160ms
# 74:	learn: 0.2711519	total: 462ms	remaining: 154ms
# 75:	learn: 0.2709571	total: 468ms	remaining: 148ms
# 76:	learn: 0.2706617	total: 475ms	remaining: 142ms
# 77:	learn: 0.2704121	total: 481ms	remaining: 136ms
# 78:	learn: 0.2701756	total: 488ms	remaining: 130ms
# 79:	learn: 0.2700183	total: 494ms	remaining: 124ms
# 80:	learn: 0.2698042	total: 502ms	remaining: 118ms
# 81:	learn: 0.2696398	total: 509ms	remaining: 112ms
# 82:	learn: 0.2694212	total: 515ms	remaining: 106ms
# 83:	learn: 0.2692610	total: 521ms	remaining: 99.3ms
# 84:	learn: 0.2688635	total: 527ms	remaining: 93ms
# 85:	learn: 0.2686333	total: 534ms	remaining: 86.9ms
# 86:	learn: 0.2684437	total: 540ms	remaining: 80.7ms
# 87:	learn: 0.2681410	total: 546ms	remaining: 74.4ms
# 88:	learn: 0.2679854	total: 552ms	remaining: 68.3ms
# 89:	learn: 0.2677356	total: 558ms	remaining: 62ms
# 90:	learn: 0.2675170	total: 564ms	remaining: 55.8ms
# 91:	learn: 0.2671109	total: 570ms	remaining: 49.6ms
# 92:	learn: 0.2668195	total: 576ms	remaining: 43.4ms
# 93:	learn: 0.2665941	total: 583ms	remaining: 37.2ms
# 94:	learn: 0.2662828	total: 589ms	remaining: 31ms
# 95:	learn: 0.2661037	total: 594ms	remaining: 24.8ms
# 96:	learn: 0.2658172	total: 601ms	remaining: 18.6ms
# 97:	learn: 0.2656350	total: 607ms	remaining: 12.4ms
# 98:	learn: 0.2654758	total: 615ms	remaining: 6.21ms
# 99:	learn: 0.2653679	total: 621ms	remaining: 0us
# CatBoost:
# Mean Squared Error (MSE): 0.08002231160223632
# Mean Absolute Error (MAE): 0.21119312728215425
# R-squared (R2): 0.7716474330815886
# Explained Variance Score: 0.7716528911003149
# Adjusted R-squared: 0.7688424322595868

# %% [markdown]
# CatBoost has given the best perfromance out of all the algorithms tried with the folowing scores
#
# *  Mean Squared Error (MSE): 0.08002231160223632
# *  Mean Absolute Error (MAE): 0.21119312728215425
# *  R-squared (R2): 0.7716474330815886
# *  Explained Variance Score: 0.7716528911003149
# *  Adjusted R-squared: 0.7688424322595868
